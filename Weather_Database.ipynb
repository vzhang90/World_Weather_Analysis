# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a287f1fadc4151a52f7908277bb66197

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"] 
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description[0]['description']})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | kieta
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | mount isa
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | teya
# Processing Record 9 of Set 1 | aswan
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | dunedin
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | shache
# Processing Record 18 of Set 1 | port hedland
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 1 | teguldet
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | jalu
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | kankakee
# Processing Record 32 of Set 1 | soe
# Processing Record 33 of Set 1 | ahipara
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | surovikino
# Processing Record 36 of Set 1 | manokwari
# Processing Record 37 of Set 1 | sistranda
# Processing Record 38 of Set 1 | huarmey
# Processing Record 39 of Set 1 | selam
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | svetlaya
# Processing Record 44 of Set 1 | altoona
# Processing Record 45 of Set 1 | caceres
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | sassandra
# Processing Record 48 of Set 1 | dogondoutchi
# Processing Record 49 of Set 1 | sitka
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | slonim
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | yulara
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | colac
# Processing Record 6 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | betsiamites
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | adrar
# Processing Record 12 of Set 2 | manaure
# Processing Record 13 of Set 2 | la ronge
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | rio gallegos
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | volodarka
# Processing Record 18 of Set 2 | estancia
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | kangaatsiaq
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | roma
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | khandyga
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | beloha
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | coaticook
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | preston
# Processing Record 36 of Set 2 | ajdabiya
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | grand gaube
# Processing Record 40 of Set 2 | florianopolis
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | palana
# Processing Record 44 of Set 2 | gumdag
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | nara
# Processing Record 47 of Set 2 | isabela
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | zhuhai
# Processing Record 1 of Set 3 | turukhansk
# Processing Record 2 of Set 3 | alofi
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | yichang
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | albanel
# Processing Record 7 of Set 3 | makakilo city
# Processing Record 8 of Set 3 | harper
# Processing Record 9 of Set 3 | jian
# Processing Record 10 of Set 3 | cananea
# Processing Record 11 of Set 3 | karasjok
# Processing Record 12 of Set 3 | santa cruz
# Processing Record 13 of Set 3 | emerald
# Processing Record 14 of Set 3 | mumford
# Processing Record 15 of Set 3 | zunyi
# Processing Record 16 of Set 3 | richards bay
# Processing Record 17 of Set 3 | pedernales
# Processing Record 18 of Set 3 | kolokani
# Processing Record 19 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 3 | sudak
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | busselton
# Processing Record 25 of Set 3 | vila velha
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | urengoy
# Processing Record 28 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 3 | cabanas
# Processing Record 30 of Set 3 | roanoke rapids
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 3 | massaguet
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | devils lake
# Processing Record 37 of Set 3 | pisco
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | khirkiya
# Processing Record 40 of Set 3 | yar-sale
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | kilindoni
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | dalby
# Processing Record 46 of Set 3 | santa isabel do rio negro
# Processing Record 47 of Set 3 | neiafu
# Processing Record 48 of Set 3 | riyadh
# Processing Record 49 of Set 3 | itarema
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | villazon
# Processing Record 2 of Set 4 | leua
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | ciudad bolivar
# Processing Record 5 of Set 4 | krasnoselkup
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | warwick
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | hamilton
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | wasilla
# Processing Record 14 of Set 4 | cavaillon
# Processing Record 15 of Set 4 | kaeo
# Processing Record 16 of Set 4 | yatou
# Processing Record 17 of Set 4 | yarega
# Processing Record 18 of Set 4 | talcahuano
# Processing Record 19 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 4 | bayan
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | kaifeng
# Processing Record 23 of Set 4 | praia
# Processing Record 24 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 4 | amga
# Processing Record 26 of Set 4 | narrabri
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | tornio
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | walvis bay
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | putina
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | kungurtug
# Processing Record 38 of Set 4 | jining
# Processing Record 39 of Set 4 | america dourada
# Processing Record 40 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | rognan
# Processing Record 44 of Set 4 | evensk
# Processing Record 45 of Set 4 | hobyo
# Processing Record 46 of Set 4 | hovd
# Processing Record 47 of Set 4 | felanitx
# Processing Record 48 of Set 4 | te anau
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | miandrivazo
# Processing Record 1 of Set 5 | okhotsk
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | palmer
# Processing Record 5 of Set 5 | mantua
# Processing Record 6 of Set 5 | ust-nera
# Processing Record 7 of Set 5 | sortland
# Processing Record 8 of Set 5 | nicoya
# Processing Record 9 of Set 5 | pochutla
# Processing Record 10 of Set 5 | vila franca do campo
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | carutapera
# Processing Record 13 of Set 5 | rawson
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | manicore
# Processing Record 17 of Set 5 | zhigansk
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | sarai
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | ganzhou
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | bilibino
# Processing Record 24 of Set 5 | saint-francois
# Processing Record 25 of Set 5 | aleksandrov gay
# Processing Record 26 of Set 5 | north platte
# Processing Record 27 of Set 5 | tecoanapa
# Processing Record 28 of Set 5 | lata
# Processing Record 29 of Set 5 | souillac
# Processing Record 30 of Set 5 | skage
# City not found. Skipping...
# Processing Record 31 of Set 5 | terrace
# Processing Record 32 of Set 5 | enshi
# Processing Record 33 of Set 5 | arequipa
# Processing Record 34 of Set 5 | ornskoldsvik
# Processing Record 35 of Set 5 | sulam
# Processing Record 36 of Set 5 | bangassou
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | kars
# Processing Record 39 of Set 5 | mogadishu
# Processing Record 40 of Set 5 | presidente epitacio
# Processing Record 41 of Set 5 | maceio
# Processing Record 42 of Set 5 | mitsamiouli
# Processing Record 43 of Set 5 | matara
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | patnos
# Processing Record 46 of Set 5 | brattvag
# Processing Record 47 of Set 5 | balkhash
# Processing Record 48 of Set 5 | san ramon
# Processing Record 49 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 50 of Set 5 | ostrovnoy
# Processing Record 1 of Set 6 | paraiso
# Processing Record 2 of Set 6 | jaramana
# City not found. Skipping...
# Processing Record 3 of Set 6 | ludvika
# Processing Record 4 of Set 6 | nyurba
# Processing Record 5 of Set 6 | kachug
# Processing Record 6 of Set 6 | kisangani
# Processing Record 7 of Set 6 | kuryk
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | kotlas
# Processing Record 10 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 6 | rawlins
# Processing Record 12 of Set 6 | mayo
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | havoysund
# Processing Record 15 of Set 6 | santa isabel
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | mangrol
# Processing Record 18 of Set 6 | shelburne
# Processing Record 19 of Set 6 | mazyr
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | broome
# Processing Record 22 of Set 6 | lima
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | zvishavane
# Processing Record 25 of Set 6 | puerto escondido
# Processing Record 26 of Set 6 | haines junction
# Processing Record 27 of Set 6 | derzhavinsk
# Processing Record 28 of Set 6 | moussoro
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | miraflores
# Processing Record 31 of Set 6 | conakry
# Processing Record 32 of Set 6 | dakar
# Processing Record 33 of Set 6 | dera bugti
# Processing Record 34 of Set 6 | sicamous
# Processing Record 35 of Set 6 | durango
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | jumla
# Processing Record 38 of Set 6 | upernavik
# Processing Record 39 of Set 6 | fort wellington
# Processing Record 40 of Set 6 | lucea
# Processing Record 41 of Set 6 | sipe sipe
# Processing Record 42 of Set 6 | hojai
# Processing Record 43 of Set 6 | arawa
# Processing Record 44 of Set 6 | tekax
# City not found. Skipping...
# Processing Record 45 of Set 6 | andenes
# Processing Record 46 of Set 6 | yerbogachen
# Processing Record 47 of Set 6 | luanda
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | zhanaozen
# Processing Record 50 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 7 | glucholazy
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | laguna
# Processing Record 4 of Set 7 | avera
# Processing Record 5 of Set 7 | ulladulla
# Processing Record 6 of Set 7 | goma
# Processing Record 7 of Set 7 | jasper
# Processing Record 8 of Set 7 | joniskis
# Processing Record 9 of Set 7 | nagua
# Processing Record 10 of Set 7 | menongue
# Processing Record 11 of Set 7 | chengde
# Processing Record 12 of Set 7 | esil
# Processing Record 13 of Set 7 | zyryanka
# Processing Record 14 of Set 7 | pacific grove
# Processing Record 15 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 7 | hualmay
# Processing Record 18 of Set 7 | langsa
# Processing Record 19 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 7 | lovington
# Processing Record 21 of Set 7 | miri
# Processing Record 22 of Set 7 | nanortalik
# Processing Record 23 of Set 7 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 24 of Set 7 | komsomolets
# Processing Record 25 of Set 7 | baykit
# Processing Record 26 of Set 7 | punta cardon
# Processing Record 27 of Set 7 | beira
# Processing Record 28 of Set 7 | lethem
# Processing Record 29 of Set 7 | eyl
# Processing Record 30 of Set 7 | vila do maio
# Processing Record 31 of Set 7 | monrovia
# Processing Record 32 of Set 7 | husavik
# Processing Record 33 of Set 7 | zeya
# Processing Record 34 of Set 7 | koumac
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | kavieng
# Processing Record 37 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 7 | srirampur
# Processing Record 39 of Set 7 | vilyuysk
# Processing Record 40 of Set 7 | birao
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | sabang
# Processing Record 44 of Set 7 | serik
# Processing Record 45 of Set 7 | boende
# Processing Record 46 of Set 7 | mahishadal
# Processing Record 47 of Set 7 | nambucca heads
# Processing Record 48 of Set 7 | tazovskiy
# Processing Record 49 of Set 7 | bambous virieux
# Processing Record 50 of Set 7 | kupang
# Processing Record 1 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | elk
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | ebeltoft
# Processing Record 6 of Set 8 | zhicheng
# Processing Record 7 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 8 | emba
# Processing Record 9 of Set 8 | san cristobal
# Processing Record 10 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | tutoia
# Processing Record 12 of Set 8 | umm lajj
# Processing Record 13 of Set 8 | hakkari
# Processing Record 14 of Set 8 | kedrovyy
# Processing Record 15 of Set 8 | padang
# Processing Record 16 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 8 | manta
# Processing Record 18 of Set 8 | surt
# Processing Record 19 of Set 8 | sioux lookout
# Processing Record 20 of Set 8 | mlalo
# Processing Record 21 of Set 8 | kattivakkam
# Processing Record 22 of Set 8 | sao filipe
# Processing Record 23 of Set 8 | lodja
# Processing Record 24 of Set 8 | dno
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | mehamn
# Processing Record 27 of Set 8 | keningau
# Processing Record 28 of Set 8 | balclutha
# Processing Record 29 of Set 8 | seydi
# Processing Record 30 of Set 8 | dafeng
# Processing Record 31 of Set 8 | ramos arizpe
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | general roca
# Processing Record 34 of Set 8 | moree
# Processing Record 35 of Set 8 | atar
# Processing Record 36 of Set 8 | namibe
# Processing Record 37 of Set 8 | vestmannaeyjar
# Processing Record 38 of Set 8 | champerico
# Processing Record 39 of Set 8 | zhezkazgan
# Processing Record 40 of Set 8 | ceres
# Processing Record 41 of Set 8 | sompeta
# Processing Record 42 of Set 8 | skoghall
# Processing Record 43 of Set 8 | sinnamary
# Processing Record 44 of Set 8 | never
# Processing Record 45 of Set 8 | college
# Processing Record 46 of Set 8 | coos bay
# Processing Record 47 of Set 8 | payo
# Processing Record 48 of Set 8 | prado
# Processing Record 49 of Set 8 | marsh harbour
# Processing Record 50 of Set 8 | takoradi
# Processing Record 1 of Set 9 | thunder bay
# Processing Record 2 of Set 9 | luang prabang
# Processing Record 3 of Set 9 | hami
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | caxito
# Processing Record 6 of Set 9 | mushie
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | hasaki
# Processing Record 9 of Set 9 | rampura
# Processing Record 10 of Set 9 | nizhnyaya omka
# Processing Record 11 of Set 9 | lavrentiya
# Processing Record 12 of Set 9 | lompoc
# Processing Record 13 of Set 9 | berlevag
# Processing Record 14 of Set 9 | ulaangom
# Processing Record 15 of Set 9 | pangkalanbuun
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | marathon
# Processing Record 18 of Set 9 | oussouye
# Processing Record 19 of Set 9 | sidi ali
# Processing Record 20 of Set 9 | kurilsk
# Processing Record 21 of Set 9 | alamogordo
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | yantal
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | qaanaaq
# Processing Record 26 of Set 9 | ilebo
# Processing Record 27 of Set 9 | sawakin
# Processing Record 28 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 9 | krasnogorodsk
# Processing Record 30 of Set 9 | sungairaya
# Processing Record 31 of Set 9 | ust-kuyga
# Processing Record 32 of Set 9 | thompson
# Processing Record 33 of Set 9 | axim
# Processing Record 34 of Set 9 | marquard
# Processing Record 35 of Set 9 | mahendranagar
# Processing Record 36 of Set 9 | aklavik
# Processing Record 37 of Set 9 | quatre cocos
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | halmstad
# Processing Record 40 of Set 9 | bembereke
# Processing Record 41 of Set 9 | san lorenzo
# Processing Record 42 of Set 9 | chokurdakh
# Processing Record 43 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 44 of Set 9 | vuktyl
# Processing Record 45 of Set 9 | olafsvik
# Processing Record 46 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 47 of Set 9 | arenal
# Processing Record 48 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 9 | san antonio
# Processing Record 50 of Set 9 | sayyan
# Processing Record 1 of Set 10 | dubai
# Processing Record 2 of Set 10 | cabo san lucas
# Processing Record 3 of Set 10 | miquelon
# Processing Record 4 of Set 10 | wodonga
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | ternate
# Processing Record 8 of Set 10 | busayra
# Processing Record 9 of Set 10 | bongaree
# Processing Record 10 of Set 10 | durant
# Processing Record 11 of Set 10 | mandalgovi
# Processing Record 12 of Set 10 | leh
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | trebisov
# Processing Record 15 of Set 10 | ankang
# Processing Record 16 of Set 10 | mudgee
# Processing Record 17 of Set 10 | damghan
# Processing Record 18 of Set 10 | bengkulu
# Processing Record 19 of Set 10 | moron
# Processing Record 20 of Set 10 | natchitoches
# Processing Record 21 of Set 10 | tougue
# Processing Record 22 of Set 10 | requena
# Processing Record 23 of Set 10 | biak
# Processing Record 24 of Set 10 | troitskoye
# Processing Record 25 of Set 10 | sangar
# Processing Record 26 of Set 10 | urkut
# Processing Record 27 of Set 10 | kamalpur
# Processing Record 28 of Set 10 | paulo ramos
# Processing Record 29 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 10 | olen
# Processing Record 31 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 10 | lake cowichan
# Processing Record 33 of Set 10 | sebastian
# Processing Record 34 of Set 10 | nargana
# Processing Record 35 of Set 10 | maragogi
# Processing Record 36 of Set 10 | maralal
# Processing Record 37 of Set 10 | kerugoya
# Processing Record 38 of Set 10 | pinheiro machado
# Processing Record 39 of Set 10 | escanaba
# Processing Record 40 of Set 10 | leningradskiy
# Processing Record 41 of Set 10 | fort nelson
# Processing Record 42 of Set 10 | magdagachi
# Processing Record 43 of Set 10 | vanavara
# Processing Record 44 of Set 10 | shingu
# Processing Record 45 of Set 10 | dingle
# Processing Record 46 of Set 10 | lafia
# Processing Record 47 of Set 10 | nouadhibou
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 10 | arrecife
# Processing Record 1 of Set 11 | bonavista
# Processing Record 2 of Set 11 | tsogni
# Processing Record 3 of Set 11 | vikulovo
# Processing Record 4 of Set 11 | qui nhon
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | san andres
# Processing Record 7 of Set 11 | daru
# Processing Record 8 of Set 11 | mayskiy
# Processing Record 9 of Set 11 | cabinda
# Processing Record 10 of Set 11 | uhlove
# Processing Record 11 of Set 11 | troitsko-pechorsk
# Processing Record 12 of Set 11 | vertientes
# Processing Record 13 of Set 11 | sungaipenuh
# Processing Record 14 of Set 11 | harindanga
# Processing Record 15 of Set 11 | cairns
# Processing Record 16 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 11 | balykshi
# Processing Record 18 of Set 11 | beatrice
# Processing Record 19 of Set 11 | chachapoyas
# Processing Record 20 of Set 11 | tingi
# Processing Record 21 of Set 11 | tukrah
# Processing Record 22 of Set 11 | karimganj
# Processing Record 23 of Set 11 | port shepstone
# Processing Record 24 of Set 11 | tombouctou
# Processing Record 25 of Set 11 | ginir
# Processing Record 26 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 11 | masvingo
# Processing Record 30 of Set 11 | teruel
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | kalat
# Processing Record 33 of Set 11 | rawah
# Processing Record 34 of Set 11 | taltal
# Processing Record 35 of Set 11 | muros
# Processing Record 36 of Set 11 | ust-kulom
# Processing Record 37 of Set 11 | hay river
# Processing Record 38 of Set 11 | mollendo
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | issenye
# Processing Record 41 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 11 | inhambane
# Processing Record 43 of Set 11 | najran
# Processing Record 44 of Set 11 | beidao
# Processing Record 45 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 11 | yumen
# Processing Record 47 of Set 11 | osoyoos
# Processing Record 48 of Set 11 | peniche
# Processing Record 49 of Set 11 | bose
# Processing Record 50 of Set 11 | barcelos
# Processing Record 1 of Set 12 | ulaanbaatar
# Processing Record 2 of Set 12 | ayagoz
# Processing Record 3 of Set 12 | maloy
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | zhaodong
# Processing Record 6 of Set 12 | monte cristi
# City not found. Skipping...
# Processing Record 7 of Set 12 | fort collins
# Processing Record 8 of Set 12 | imbituba
# Processing Record 9 of Set 12 | villamontes
# Processing Record 10 of Set 12 | uchaly
# Processing Record 11 of Set 12 | sandane
# Processing Record 12 of Set 12 | mountain home
# Processing Record 13 of Set 12 | esperance
# Processing Record 14 of Set 12 | kresttsy
# Processing Record 15 of Set 12 | lamar
# Processing Record 16 of Set 12 | arcoverde
# Processing Record 17 of Set 12 | algiers
# Processing Record 18 of Set 12 | milkovo
# Processing Record 19 of Set 12 | hervey bay
# Processing Record 20 of Set 12 | los aquijes
# Processing Record 21 of Set 12 | nea fokaia
# Processing Record 22 of Set 12 | mufumbwe
# Processing Record 23 of Set 12 | abu kamal
# Processing Record 24 of Set 12 | pasighat
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | saint-georges
# Processing Record 27 of Set 12 | marzuq
# Processing Record 28 of Set 12 | loubomo
# Processing Record 29 of Set 12 | gao
# Processing Record 30 of Set 12 | tuatapere
# Processing Record 31 of Set 12 | cap-aux-meules
# Processing Record 32 of Set 12 | grand-santi
# Processing Record 33 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 12 | shahganj
# Processing Record 35 of Set 12 | maningrida
# Processing Record 36 of Set 12 | lamu
# Processing Record 37 of Set 12 | marsa matruh
# Processing Record 38 of Set 12 | meylan
# Processing Record 39 of Set 12 | shaowu
# Processing Record 40 of Set 12 | kichera
# Processing Record 41 of Set 12 | lebork
# Processing Record 42 of Set 12 | slavyanka
# Processing Record 43 of Set 12 | gravdal
# Processing Record 44 of Set 12 | challans
# Processing Record 45 of Set 12 | elliot lake
# Processing Record 46 of Set 12 | opuwo
# Processing Record 47 of Set 12 | wadena
# Processing Record 48 of Set 12 | egvekinot
# Processing Record 49 of Set 12 | aksu
# Processing Record 50 of Set 12 | chabahar
# Processing Record 1 of Set 13 | cherepovets
# Processing Record 2 of Set 13 | macas
# Processing Record 3 of Set 13 | touros
# Processing Record 4 of Set 13 | orange
# Processing Record 5 of Set 13 | shanhetun
# Processing Record 6 of Set 13 | green river
# Processing Record 7 of Set 13 | taboga
# Processing Record 8 of Set 13 | pointe michel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 558

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Rikitea -23.1203 -134.9692     72.99        73          68       13.04
# 1     Hobart -42.8794  147.3294     63.05        49          75        8.05
# 2      Bluff -46.6000  168.3333     50.81        59          57       20.67
# 3      Kieta  -6.2167  155.6333     83.07        77          96        6.96
# 4     Bethel  41.3712  -73.4140     48.51        59          75       19.57
# 5  Mount Isa -20.7333  139.5000     89.37        18           0       16.11
# 6       Teya  60.3778   92.6267      1.94        95         100        6.11
# 7      Aswan  24.0934   32.9070     61.90        82           0        4.61
# 8    Iqaluit  63.7506  -68.5145    -16.31        62          20        9.22
# 9      Lagoa  39.0500  -27.9833     61.41        75           0        7.54
#
#   Country Current Description
# 0      PF       broken clouds
# 1      AU       broken clouds
# 2      NZ       broken clouds
# 3      PG       moderate rain
# 4      US       broken clouds
# 5      AU           clear sky
# 6      RU          light snow
# 7      EG           clear sky
# 8      CA          few clouds
# 9      PT           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Rikitea      PF -23.1203 -134.9692     72.99        73          68
# 1     Hobart      AU -42.8794  147.3294     63.05        49          75
# 2      Bluff      NZ -46.6000  168.3333     50.81        59          57
# 3      Kieta      PG  -6.2167  155.6333     83.07        77          96
# 4     Bethel      US  41.3712  -73.4140     48.51        59          75
# 5  Mount Isa      AU -20.7333  139.5000     89.37        18           0
# 6       Teya      RU  60.3778   92.6267      1.94        95         100
# 7      Aswan      EG  24.0934   32.9070     61.90        82           0
# 8    Iqaluit      CA  63.7506  -68.5145    -16.31        62          20
# 9      Lagoa      PT  39.0500  -27.9833     61.41        75           0
#
#    Wind Speed Current Description
# 0       13.04       broken clouds
# 1        8.05       broken clouds
# 2       20.67       broken clouds
# 3        6.96       moderate rain
# 4       19.57       broken clouds
# 5       16.11           clear sky
# 6        6.11          light snow
# 7        4.61           clear sky
# 8        9.22          few clouds
# 9        7.54           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "c:/users/zhang/world_weather_analysis/weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
